# %% [markdown]
# start the visualazation using matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,1,10)
y = x**2
plt.plot(x,y)
plt.title("hello")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')
